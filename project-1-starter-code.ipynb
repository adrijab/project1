# %% [markdown]
# <img src="http://i.imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 1
#
# ### Building "Pokemon Stay"
#
# ---
#
# After reading the gushing praise for Pokemon Go you decide to download it and try it out for yourself. Yet a couple hours of play later you find yourself disappointed by the fact that you _actually_ have to move around outside.
#
# Though just a beginner programmer, you decide to make your own iteration on the genre: "Pokemon Stay". In this version players still need to move, but just from website to website. Pokemon gyms are now popular cyber-destinations, and catching pokemon in the "wild" simply requires browsing the internet for hours in the comfort of your home.
#
# ---
#
# #### Package imports
#
# The `pprint` package below is the only package imported here, and it's not even strictly required to do any of the project. Printing python variables and objects with pprint can help to format them in a "prettier" way.

# %%
from pprint import pprint

# %% [markdown]
# <img src=http://i.imgur.com/l5NasQj.png style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1. Defining a player
#
# ---
#
# The player variables are:
#
#     player_id : id code unique to each player (integer)
#     player_name : entered name of the player (string)
#     time_played : number of time played the game in minutes (float)
#     player_pokemon: the player's captured pokemon (dictionary)
#     gyms_visited: ids of the gyms that a player has visited (list)
#
# Create a player. The dictionary and list variables should just be defined as empty at this point.

# %%
# Intiatlising the variables for player

player_id = 0 
player_name = ''
time_played = 0.0
player_pokemon = {}
gyms_visited = []

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2. Defining "gym" locations
#
# ---
#
# As the sole programmer, Pokemon Stay will have to start small. To begin, there will be 10 different gym location websites on the internet. The gym locations are:
#
#     1. 'reddit.com'
#     2. 'amazon.com'
#     3. 'twitter.com'
#     4. 'linkedin.com'
#     5. 'ebay.com'
#     6. 'netflix.com'
#     7. 'udacity.com'
#     8. 'stackoverflow.com'
#     9. 'github.com'
#     10. 'quora.com'
#
# 1. Set up a list of all the gym locations. This will be a list of strings.
# 2. Append two of these locations to your player's list of visited gyms.
# 3. Print the list.

# %%
# Example output:

# listing the gym locations with the 10 different locations provided.

Gym_Locations = [ 'reddit.com',
 'amazon.com',
 'twitter.com', 'linkedin.com',
 'ebay.com',
'netflix.com',
'udacity.com',
 'stackoverflow.com',
'github.com',
'quora.com']
# printing gym_locations
print Gym_Locations

# ['amazon.com', 'ebay.com']
# Out:
# ['reddit.com', 'amazon.com', 'twitter.com', 'linkedin.com', 'ebay.com', 'netflix.com', 'udacity.com', 'stackoverflow.com', 'github.com', 'quora.com']

# %%
# Example output:
#['amazon.com', 'ebay.com']

#Defined Gym_Locations with all the information
Gym_Locations = ['reddit.com', 'amazon.com', 'twitter.com',  'linkedin.com', 'ebay.com', 'netflix.com', 'udacity.com', 'stackoverflow.com', 'github.com', 'quora.com']
#appending to player list of visited gym individually
gyms_visited.append('reddit.com')
gyms_visited.append('amazon.com')
#printing gyms_visited
print(gyms_visited)
# Out:
# ['reddit.com', 'amazon.com', 'reddit.com', 'amazon.com']

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. Create a pokedex
#
# ---
#
# We also need to create some pokemon to catch. Each pokemon will be defined by these variables:
#
#     pokemon_id : unique identifier for each pokemon (integer)
#     name : the name of the pokemon (string)
#     type : the category of pokemon (string)
#     hp : base hitpoints (integer)
#     attack : base attack (integer)
#     defense : base defense (integer)
#     special_attack : base special attack (integer)
#     special_defense : base sepecial defense (integer)
#     speed : base speed (integer)
#
# We are only going to create 3 different pokemon with these `pokemon_id` and `pokemon_name` values:
#
#     1 : 'charmander'
#     2 : 'squirtle'
#     3 : 'bulbasaur'
#
# Create a dictionary that will contain the pokemon. The keys of the dictionary will be the `pokemon_id` and the values will themselves dictionaries that contain the other pokemon variables. The structure of the pokedex dictionary will start like so:
#
#      {
#          1: {
#                  'name':'charmander',
#                  'type':'fire',
#                  ...
#
# The `type` of charmander, squirtle, and bulbasaur should be `'fire'`, `'water'`, and `'poison'` respectively. The other values are up to you, make them anything you like!
#
# Print the pokedex dictionary with the 3 pokemon.

# %%
#Created a dictionary for Pokeman manually with ids (for pokemman) as the keys and different variables as the values



Pokedex = { 
1: 
    {       
       'name':'charmander',
       'type':'fire', 
        'hp' : 12,
        'attack' : 25,
        'defense' : 65,
        'special_attack' : 12,
        'special_defense' : 14,
        'speed' :10},
        
   2: {  'name': 'squirtle',
         'type':'water', 
         'hp' : 15,
        'attack' : 17,
        'defense' :43,
        'special_attack' :14,
        'special_defense' :17,
        'speed' :12,},
    3: {'name':'bulbasaur',
        'type':'poison', 
         'hp' : 23,
        'attack' : 12,
        'defense' :34,
        'special_attack' :32,
        'special_defense' :15,
        'speed' :13}}

#Printing Pokedex dictionary to see the output
print(Pokedex)
# Out:
# {1: {'attack': 25, 'defense': 65, 'name': 'charmander', 'special_attack': 12, 'speed': 10, 'hp': 12, 'type': 'fire', 'special_defense': 14}, 2: {'attack': 17, 'defense': 43, 'name': 'squirtle', 'special_attack': 14, 'speed': 12, 'hp': 15, 'type': 'water', 'special_defense': 17}, 3: {'attack': 12, 'defense': 34, 'name': 'bulbasaur', 'special_attack': 32, 'speed': 13, 'hp': 23, 'type': 'poison', 'special_defense': 15}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 4. Create a data structure for players
#
# ---
#
# ### 4.1
#
# In order to maintain a database of multiple players, create a dictionary that keeps track of players indexed by `player_id`.
#
# The keys of the dictionary will be `player_id` and values will be dictionaries containing each player's variables (from question 1). **The values in the player's dictionary will be the variables you assigned in question 1.**
#
# Construct the `players` dictionary and insert the player that you defined in question 1, then print `players`.

# %%
# created players data struture by using player_ids as keys and player variables as values.
Players = {1: {'gyms_visited': ['netflix.com', 'ebay.com'], 'player_name': 'Ash','player_pokemon': {},'time_played': 10.0}, 
  3: {'gyms_visited': ['twitter.com', 'linkedin.com'],'player_name': 'Drew', 'player_pokemon': {},'time_played': 12.0}, 
  4: {'gyms_visited': ['udacity.com', 'stackoverflow.com'], 'player_name': 'Bob', 'player_pokemon': {}, 'time_played': 9.0}, 
  5: {'gyms_visited': ['github.com', 'quora.com'], 'player_name': 'Tom', 'player_pokemon': {}, 'time_played': 9.5} 
  }

#printing Players to see the output
print(Players)
# Out:
# {1: {'time_played': 10.0, 'gyms_visited': ['netflix.com', 'ebay.com'], 'player_name': 'Ash', 'player_pokemon': {}}, 3: {'time_played': 12.0, 'gyms_visited': ['twitter.com', 'linkedin.com'], 'player_name': 'Drew', 'player_pokemon': {}}, 4: {'time_played': 9.0, 'gyms_visited': ['udacity.com', 'stackoverflow.com'], 'player_name': 'Bob', 'player_pokemon': {}}, 5: {'time_played': 9.5, 'gyms_visited': ['github.com', 'quora.com'], 'player_name': 'Tom', 'player_pokemon': {}}}

# %% [markdown]
# ---
#
# ### 4.2
#
# Create a new player with `player_id = 2` in the `players` dictionary. Leave the `'player_pokemon'` dictionary empty. Append `'stackoverflow.com'` and `'github.com'` to the `'gyms_visited'` list for player 2.
#
# The `'player_name'` and `'time_played'` values are up to you, but must be a string and float, respectively.
#
# Remember, the player_id is the key for the player in the players dictionary.
#
# Print the `players` dictionary with the new player inserted.

# %%
# creating a new player within dictionary 
New_Player = {2: {'gyms_visited': ['stackoverflow.com', 'github.com'],'player_name': 'Brock', 'player_pokemon': {},'time_played': 10.0}}

#printing new player
print(New_Player)
 
#Appending new player within the Players dictionary
Players.update(New_Player)

#Printing players dictionary with the new players
print(Players)
# Out:
# {2: {'time_played': 10.0, 'gyms_visited': ['stackoverflow.com', 'github.com'], 'player_name': 'Brock', 'player_pokemon': {}}}
# {1: {'time_played': 10.0, 'gyms_visited': ['netflix.com', 'ebay.com'], 'player_name': 'Ash', 'player_pokemon': {2: {'attack': 17, 'defense': 43, 'name': 'squirtle', 'special_attack': 14, 'speed': 12, 'hp': 15, 'type': 'water', 'special_defense': 17}}}, 2: {'time_played': 10.0, 'gyms_visited': ['stackoverflow.com', 'github.com'], 'player_name': 'Brock', 'player_pokemon': {}}, 3: {'time_played': 12.0, 'gyms_visited': ['twitter.com', 'linkedin.com'], 'player_name': 'Drew', 'player_pokemon': {}}, 4: {'time_played': 9.0, 'gyms_visited': ['udacity.com', 'stackoverflow.com'], 'player_name': 'Bob', 'player_pokemon': {}}, 5: {'time_played': 9.5, 'gyms_visited': ['github.com', 'quora.com'], 'player_name': 'Tom', 'player_pokemon': {}}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 5. Add captured pokemon for each player
#
# ---
#
# The `'player_pokemon'` keyed dictionaries for each player keep track of which of the pokemon each player has.
#
# The keys of the `'player_pokemon'` dictionaries are the pokemon ids that correspond to the ids in the `pokedex` dictionary you created earlier. The values are integers specifying the stats for the pokemon.
#
# Give player 1 a squirtle. Give player 2 charmander and a bulbasaur.
#
# Print the players dictionary after adding the pokemon for each player.

# %%
#Defined empty list 
New_Player_Pokemon = {}
#iterate over Players
for key, value in Players.items():
#   print(key)
  #  print(value)
    #Inserting Pokemons for player 1 and 2 on player_pokemon
    if key == 1:
        New_Player_Pokemon.update({key : value})
        for k, v in Pokedex.items():
            if (v['name']) == 'squirtle':
                x = New_Player_Pokemon[key]
                x['player_pokemon'].update({k:v})            
    elif key == 2:
        New_Player_Pokemon.update({key : value})
        for k, v in Pokedex.items():
            if ((v['name']) == 'charmander') or ((v['name']) == 'bulbasaur'):
                x = New_Player_Pokemon[key]
                x['player_pokemon'].update({k:v})
                
#printing to see output
print(New_Player_Pokemon)
# Out:
# {1: {'time_played': 10.0, 'gyms_visited': ['netflix.com', 'ebay.com'], 'player_name': 'Ash', 'player_pokemon': {2: {'attack': 17, 'defense': 43, 'name': 'squirtle', 'special_attack': 14, 'speed': 12, 'hp': 15, 'type': 'water', 'special_defense': 17}}}, 2: {'time_played': 10.0, 'gyms_visited': ['stackoverflow.com', 'github.com'], 'player_name': 'Brock', 'player_pokemon': {1: {'attack': 25, 'defense': 65, 'name': 'charmander', 'special_attack': 12, 'speed': 10, 'hp': 12, 'type': 'fire', 'special_defense': 14}, 3: {'attack': 12, 'defense': 34, 'name': 'bulbasaur', 'special_attack': 32, 'speed': 13, 'hp': 23, 'type': 'poison', 'special_defense': 15}}}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 6. What gyms have players visited?
#
# ---
#
# Write a for-loop that:
#
# 1. Iterates through the `pokemon_gyms` list of gym locations you defined before.
# 2. For each gym, iterate through each player in the `players` dictionary with a second, internal for-loop.
# 3. If the player has visited the gym, print out "[player] has visited [gym location].", filling in [player] and [gym location] with the current player's name and current gym location.

# %%
# Example output:
# Ash has visited amazon.com.
# Ash has visited ebay.com.
# Ash has visited amazon.com.
# Brock has visited stackoverflow.com.
# Brock has visited github.com.


## created players data struture by using player_ids as keys and player variables as values.


for location in Gym_Locations:
    for key, value in Players.items():
        #print(value['gyms_visited'])
        if location in value['gyms_visited']:
            print value['player_name'] +' has visited ' + location + '.'
# Out:
# Drew has visited twitter.com.
# Drew has visited linkedin.com.
# Ash has visited ebay.com.
# Ash has visited netflix.com.
# Bob has visited udacity.com.
# Bob has visited stackoverflow.com.
# Tom has visited github.com.
# Tom has visited quora.com.

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 7. Calculate player "power".
#
# ---
#
# Define a function that will calculate a player's "power". Player power is defined as the sum of the base statistics all of their pokemon.
#
# Your function will:
#
# 1. Accept the `players` dictionary, `pokedex` dictionary, and a player_id as arguments.
# 2. For the specified player_id, look up that player's pokemon and their level(s).
# 3. Find and aggregate the attack and defense values for each of the player's pokemon from the `pokedex` dictionary.
# 4. Print "[player name]'s power is [player power].", where the player power is the sum of the base statistics for all of their pokemon.
# 5. Return the player's power value.
#
# Print out the pokemon power for each of your players.

# %%
# Example output:
#
# Ash's power is 57.
# 57
# Brock's power is 119.
# 119
# to do this problem we need to consider the New_Pokeman_Player dictionary that we created in 


#define function. 
#for specified id, locate pokemon and add the corresponding values for attack and defense for each pokemon for specified player
def Player_Power(p, q, r):
    Power = 0
    for key, value in p.items():
        if r == key:
            x = value['player_pokemon']
            for k, v in x.items(): 
                Power += v['attack'] + v['defense'] 
    return Power
#printing players' powers
v = Player_Power(New_Player_Pokemon, Pokedex, 1)
print(New_Player_Pokemon[1]['player_name'] + '\'s' + ' power' + ' is ' + str(v) + '.')
v = Player_Power(New_Player_Pokemon, Pokedex, 2)
print(New_Player_Pokemon[2]['player_name'] + '\'s' + ' power' + ' is ' + str(v) + '.')
# Out:
# Ash's power is 60.
# Brock's power is 136.

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 8. Load a pokedex file containing all the pokemon
#
# ---
#
# ### 8.1
#
# Now we have access to the raw base stats on all of the pokemon, scraped from the web.
#
# The provided code below loads information from a comma separated value (csv) file. You need to parse this string into a more useable format. The format of the string is:
#
# - Rows are separated by newline characters: \n
# - Columns are separated by commas: ,
# - All cells in the csv are double quoted. Ex: "PokedexNumber" is the first cell of the first row.
#
# Using for-loops, create a list of lists where each list within the overall list is a row of the csv/matrix, and each element in that list is a cell in that row. Additional criteria:
#
# 1. Quotes are removed from each cell item.
# 2. Numeric column values are converted to floats.
# 3. There are some cells that are empty and have no information. For these cells put a -1 value in place.
#
# The first three lists in your pokedex list should look like so:
#
#     ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
#     [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
#     [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# %%
# Code to read in pokedex info

raw_pd = ''
pokedex_file = '../../datasets/pokemon/pokedex_basic.csv'
with open(pokedex_file, 'r') as f:
    raw_pd = f.read()
#print(raw_pd) 
#print(type(raw_pd))
#print(raw_pd)
#Creating an empty list
Pokemon_list = []
# creating a list of the raw_pd files
x = raw_pd.splitlines()
#print(x)
#Accessing the first element of file
y = (x[0])
#Going over each element of x and replacing " by blank.
for i in x:
    c =i.replace('"', '')
    #print(c)
    y = c.split(',')
    #print (y)
    p = [float(j) if j.isdigit() else (-1 if j == "" else j) for j in y]
    #for j in y:
     #   if j.isdigit():
        #    fl = float(j)
    print(p)

#new_items = [x if x % 2 else None for x in items]
# Out:
# ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
# [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
# [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]
# [3.0, 'Venusaur', 'GrassPoison', 525.0, 80.0, 82.0, 83.0, 100.0, 100.0, 80.0]
# [3.0, 'VenusaurMega Venusaur', 'GrassPoison', 625.0, 80.0, 100.0, 123.0, 122.0, 120.0, 80.0]
# [4.0, 'Charmander', 'Fire', 309.0, 39.0, 52.0, 43.0, 60.0, 50.0, 65.0]
# [5.0, 'Charmeleon', 'Fire', 405.0, 58.0, 64.0, 58.0, 80.0, 65.0, 80.0]
# [6.0, 'Charizard', 'FireFlying', 534.0, 78.0, 84.0, 78.0, 109.0, 85.0, 100.0]
# [6.0, 'CharizardMega Charizard X', 'FireDragon', 634.0, 78.0, 130.0, 111.0, 130.0, 85.0, 100.0]
# [6.0, 'CharizardMega Charizard Y', 'FireFlying', 634.0, 78.0, 104.0, 78.0, 159.0, 115.0, 100.0]
# [7.0, 'Squirtle', 'Water', 314.0, 44.0, 48.0, 65.0, 50.0, 64.0, 43.0]
# ...

# %% [markdown]
# <img src="http://imgur.com/gGrau8s.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 8.2 Parse the raw pokedex with list comprehensions
#
# ---
#
# Perform the same parsing as above, but **using only a single list comprehension** instead of for loops. You may have nested list comprehensions within the main list comprehension! The output should be exactly the same.

# %%
# Example output (first 3 sublists):
#
# ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
# [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
# [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]
raw_pd = ''
pokedex_file = '../../datasets/pokemon/pokedex_basic.csv'
with open(pokedex_file, 'r') as f:
    raw_pd = f.read()

x = raw_pd.splitlines()
#print (x)

#y = [i.replace('"', '') for i in x]
#z = [j.split(',') for j in y]
#print(z[0])
#[float(p) if p.isdigit() else (-1 if p == "" else p) for p in z]
#print(type(p))
#cc = [y for y in [j.split(',') for j in [i.replace('"', '') for i in x] ]]
#print(cc[0])



Parsed_Pokedex = [[float(p) if p.isdigit() else (-1 if p == "" else p) for p in y] for y in [j.split(',') for j in [i.replace('"', '') for i in x]]]
#print([p for p in y for y in [j.split(',') for j in [i.replace('"', '') for i in x] ]])


#[i.replace('"', '')
# Out:
# [['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed'], [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0], [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0], [3.0, 'Venusaur', 'GrassPoison', 525.0, 80.0, 82.0, 83.0, 100.0, 100.0, 80.0], [3.0, 'VenusaurMega Venusaur', 'GrassPoison', 625.0, 80.0, 100.0, 123.0, 122.0, 120.0, 80.0], [4.0, 'Charmander', 'Fire', 309.0, 39.0, 52.0, 43.0, 60.0, 50.0, 65.0], [5.0, 'Charmeleon', 'Fire', 405.0, 58.0, 64.0, 58.0, 80.0, 65.0, 80.0], [6.0, 'Charizard', 'FireFlying', 534.0, 78.0, 84.0, 78.0, 109.0, 85.0, 100.0], [6.0, 'CharizardMega Charizard X', 'FireDragon', 634.0, 78.0, 130.0, 111.0, 130.0, 85.0, 100.0], [6.0, 'CharizardMega Charizard Y', 'FireFlying', 634.0, 78.0, 104.0, 78.0, 159.0, 115.0, 100.0], [7.0, 'Squirtle', 'Water', 314.0, 44.0, 48.0, 65.0, 50.0, 64.0, 43.0], [8.0, 'Wartortle', 'Water', 405.0, 59.0, 63.0, 80.0, 65.0, 80.0, 58
# ...

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 9. Write a function to generate the full pokedex
#
# ---
#
# Write a function that recreates the pokedex you made before, but with the data read in from the full pokemon file. The `PokedexNumber` should be used as the `pokemon_id` key values for the dictionary of pokemon.
#
# Your function should:
#
# 1. Take the parsed pokedex information you created above as an argument.
# 2. Return a dictionary in the same format as your original pokedex you created before containing the information from the parsed full pokedex file.
#
# To test the function, print out the pokemon with id = 100.

# %%
# Example output:



raw_pd = ''
pokedex_file = '../../datasets/pokemon/pokedex_basic.csv'
with open(pokedex_file, 'r') as f:
    raw_pd = f.read()

x = raw_pd.splitlines()

def Pokemon(X):
    p = {}
    ind_Pok = 0;
    ind_el_N = 0;
    ind_el_Ty = 0;
    ind_el_To = 0;
    ind_el_HP = 0;
    ind_el_A = 0;
    ind_el_D = 0;
    ind_el_SA = 0; 
    ind_el_SD = 0;
    ind_el_S = 0;  
    
    for idx, val in enumerate(X): 
        if idx == 0:
            for i, j in enumerate(val):
                if j == 'PokedexNumber':
                    ind_Pok = i
                elif j == 'Name':
                    ind_el_N = i
                elif j ==  'Type':
                    ind_el_Ty = i
                elif j ==  'Total':
                    ind_el_To = i
                elif j ==  'HP':
                    ind_el_HP = i
                elif j == 'Attack':
                    ind_el_A = i
                elif j == 'Defense':
                    ind_el_D = i
                elif j == 'SpecialAttack':
                    ind_el_SA = i
                elif j == 'SpecialDefense':
                    ind_el_SD = i
                elif j == 'Speed':
                     ind_el_S = i
        elif idx > 0:
            q = {'Attack': val[ind_el_A] ,  'Defense': val[ind_el_D],'HP': val[ind_el_HP],
                 'Name': val[ind_el_N], 'SpecialAttack': val[ind_el_SA], 'SpecialDefense': val[ind_el_SD], 
                 'Speed': val[ind_el_S], 'Total': val[ind_el_To],'Type': val[ind_el_Ty]}   
            #assigning keys to all values in q
            p[val[ind_Pok]] = q
            
    return p


Pokedex_dict  = Pokemon(Parsed_Pokedex)
print(Pokedex_dict)
# print(Parsed_Pokedex)
print(Pokedex_dict[200.0])
# Out:
# {1.0: {'Type': 'GrassPoison', 'Attack': 49.0, 'Defense': 49.0, 'Name': 'Bulbasaur', 'Speed': 45.0, 'HP': 45.0, 'Total': 318.0, 'SpecialAttack': 65.0, 'SpecialDefense': 65.0}, 2.0: {'Type': 'GrassPoison', 'Attack': 62.0, 'Defense': 63.0, 'Name': 'Ivysaur', 'Speed': 60.0, 'HP': 60.0, 'Total': 405.0, 'SpecialAttack': 80.0, 'SpecialDefense': 80.0}, 3.0: {'Type': 'GrassPoison', 'Attack': 100.0, 'Defense': 123.0, 'Name': 'VenusaurMega Venusaur', 'Speed': 80.0, 'HP': 80.0, 'Total': 625.0, 'SpecialAttack': 122.0, 'SpecialDefense': 120.0}, 4.0: {'Type': 'Fire', 'Attack': 52.0, 'Defense': 43.0, 'Name': 'Charmander', 'Speed': 65.0, 'HP': 39.0, 'Total': 309.0, 'SpecialAttack': 60.0, 'SpecialDefense': 50.0}, 5.0: {'Type': 'Fire', 'Attack': 64.0, 'Defense': 58.0, 'Name': 'Charmeleon', 'Speed': 80.0, 'HP': 58.0, 'Total': 405.0, 'SpecialAttack': 80.0, 'SpecialDefense': 65.0}, 6.0: {'Type': 'FireFlying', 'Attack': 104.0, 'Defense': 78.0, 'Name': 'CharizardMega Charizard Y', 'Speed': 100.0, 'HP': 78.0
# ...

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Write a function to generate a "filtered" pokedex
# ---
# Your function should:
# 1. Take the parsed pokedex information you created above as an argument.
# 1. Take a dictionary as a parameter with keys matching the features of the Pokedex, filtering by exact match for string type values, and/or filter continuous variables specified value that is greater than or equal to the dictionary key parameter.
# 1. Return multiple elements from the Pokedex
#
# Example:
#
# ```python
#
# # Only filter based on parameters passed
# filter_options = {
#     'Attack':   25,
#     'Defense':  30,
#     'Type':     'Electric'
# }
#
# # Return records with attack >= 24, defense >= 30, and type == "Electric"
# # Also anticipate that other paramters can also be passed such as "SpecialAttack", "Speed", etc.
# filtered_pokedex(pokedex_data, filter=filter_options)
#
# # Example output:
# # [{'Attack': 30.0,
# #  'Defense': 50.0,
# #  'HP': 40.0,
# #  'Name': 'Voltorb',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  {'Attack': 30.0,
# #  'Defense': 33.0,
# #  'HP': 32.0,
# #  'Name': 'Pikachu',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  ... etc
# #  ]
#
# ```

# %%
def filtered_pokedex(Pok_Dict, f_options):
    Filter_list = []
    x = True
# iterate through all pokemon in the Pokedex_Dict dictionary
    for poke_id, poke_dict in Pok_Dict.iteritems():
    # iterate through each pokemon's parameters    
    #for param_key, param_val in poke_dict:
    # check to see if pokemon parameter values satisfy the passed in filter options   
        for param_key, param_val in f_options.iteritems():
            if isinstance(param_val, float):
                if poke_dict[param_key] >= param_val:
                    x = True
                else:
                    x = False
                    break
                #return Filter_list.append(poke_dict)
            elif poke_dict[param_key] == param_val:
                x = True
                #return Filter_list.append(poke_dict[param_key])
            else:
                x = False
                break
        if x == True:
            Filter_list.append(poke_dict)
    return Filter_list

#Defining filter options            
filter_options = {
    'Attack':   25.0,
    'Defense':  30.0,
    'Type':     'Electric'
}            
            
            
#calling the function
# Passed the assigned Pokedex_dict from problem 9 and filter options defined above 
filtered_pokedex(Pokedex_dict, filter_options)
# Out:
# [{'Attack': 55.0,
#   'Defense': 40.0,
#   'HP': 35.0,
#   'Name': 'Pikachu',
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 50.0,
#   'Speed': 90.0,
#   'Total': 320.0,
#   'Type': 'Electric'},
#  {'Attack': 90.0,
#   'Defense': 55.0,
#   'HP': 60.0,
#   'Name': 'Raichu',
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 80.0,
#   'Speed': 110.0,
#   'Total': 485.0,
#   'Type': 'Electric'},
#  {'Attack': 30.0,
#   'Defense': 50.0,
#   'HP': 40.0,
#   'Name': 'Voltorb',
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 55.0,
#   'Speed': 100.0,
#   'Total': 330.0,
#   'Type': 'Electric'},
#  {'Attack': 50.0,
#   'Defense': 70.0,
#   'HP': 60.0,
#   'Name': 'Electrode',
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 80.0,
#   'Speed': 140.0,
#   'Total': 480.0,
#   'Type': 'Electric'},
#  {'Attack': 83.0,
#   'Defense': 57.0,
#   'HP': 65.0,
#   'Name': 'Electabuzz',
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 85.0,
#   'Speed': 105.0,
#   'Total': 490.0,
# ...
